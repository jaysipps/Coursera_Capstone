# %% [markdown]
# # Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute.

# %% [markdown]
# ##### I have decided to work with the city of Hamilton, Ontario. It is a smaller choice than Toronto, but it is still a large enough city to have plenty of neighborhood data to work with. I want to see how opening a business in a Hamilton neighborhood would be different than in Toronto.

# %% [markdown]
# ##### The business I have chosen to open is a bakery. I chose this because I feel like this is a realistic and somewhat common business proposal, so there may be real world results that can use my findings for their future business proposals. I believe that using a realistic business such as a bakery will better allow me to pitch the proposal to the hypothetical future business partners or loan companies.

# %% [markdown]
# ##### I will be able to use the foursquare data to see what neighborhoods have similar businesses (such as cafes and other bakeries), and I will also look at proximity to Ontario Cannabis dispensaries. A close proximity to a cannabis dispensary would make an excellent selling point for the location. This data should help me accurately suggest a neighborhood for the bakery business. Once I analyze the foursquare data, I can use it to differentiate multiple neighborhoods that may fit both of these prerequisites. I can further sort by accessibility from major hotspots such as malls for example.

# %% [markdown]
# ##### I will webscrape neighborhood data from Wikipedia and filter the results to include only L8 and L9 postal codes for the Hamilton area. I can then use the foursquare data to cluster neighborhoods and see what neighborhoods have the fewest bakeries and cafes, while still having a nearby cannabis dispensary. This should allow me to narrow down the proper place to propose the new business.
